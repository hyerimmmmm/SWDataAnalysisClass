# %% [markdown]
# ### 1. 문제 정의(목표)
# - 미국의 중심 도시인 보스턴의 1970년대 거주지에 대한 데이터를 바탕으로 주택가격을 예측해보자

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 2. 데이터 수집
# - 보스턴 집 값 데이터셋 로드

# %%
data = pd.read_csv('./data/boston_house.csv')
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ![image.png](attachment:b1075a4f-b361-4824-b30d-d90411dfacfc.png)
#
# - MEDV: 주택가격

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ### 3. 데이터 전처리
# - 필요 없음

# %% [markdown]
# ### 4. 탐색적 데이터 분석

# %%
# 특성간 상관계수 출력
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
plt.figure(figsize = (15, 15))

# 상관계수 히트맵
sns.heatmap(
    data = data.corr(),
    annot = True, # annotation: 각 셀에 상관계수 값 출력 여부

    #히트맵 색상
    cmap = 'Reds'
)
# Out:
# <Axes: >

# %% [markdown]
# - 데이터로만 보았을 때, 주택가격(MEDV)과의 상관관계가 높은 특성은 RM(주택당 방 개수), LSTAT(소득하위계층 비율)

# %% [markdown]
# ### 5. 모델링(모델 선택, 학습, 평가)
# - 문제, 정답 데이터 설정
# - 학습, 평가 데이터 설정

# %%
# 먼저 문제, 정답으로 나눈 수, trian_test_split으로 학습, 평가까지 분리

# %%
data.shape
# Out:
# (506, 14)

# %%
y = data['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
# X = data.drop('MEDV', axis = 1)
# X = data.iloc[:, :13]
X = data.loc[:, :'LSTAT']
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
# 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (152, 13)
# (354,)
# (152,)

# %% [markdown]
# ### 선형 회귀 모델 적용

# %%
# 선형회귀모델 임포트
from sklearn.linear_model import LinearRegression

# 평가지표 MSE 임포트
from sklearn.metrics import mean_squared_error

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# w값 출력(특성 13개)
# y = w1x1 + w2x2 + w3x3 ...+ w13x13 + b
linear_model.coef_
# Out:
# array([-1.54486040e-01,  4.13948217e-02, -2.53765225e-02,  7.86055259e-01,
#        -1.29365836e+01,  4.03952301e+00, -1.05354914e-02, -1.33498644e+00,
#         3.18272501e-01, -1.26427463e-02, -9.77287564e-01,  1.26714702e-02,
#        -4.62052176e-01])

# %%
# 표기법 전환
np.set_printoptions(
    suppress=True, # 지수표기법 억제
    precision=4 # 소수점 4자리까지
)

# %%
linear_model.coef_
# Out:
# array([ -0.1545,   0.0414,  -0.0254,   0.7861, -12.9366,   4.0395,
#         -0.0105,  -1.335 ,   0.3183,  -0.0126,  -0.9773,   0.0127,
#         -0.4621])

# %%
# 데이터 프레임 생성
coef_df = pd.DataFrame({ # 데이터 프레임을 만든다
    'Feature': X_train.columns, # 컬럼명은 Feature, 데이터는 X_train의 컬럼명을 쓰겠다
    'Coefficient': linear_model.coef_ # 컬럼명은 Coefficient, 데이터는 linear_model.coef_를 쓰겠다
})

coef_df
# Out:
#     Feature  Coefficient
# 0      CRIM    -0.154486
# 1        ZN     0.041395
# 2     INDUS    -0.025377
# 3      CHAS     0.786055
# 4       NOX   -12.936584
# 5        RM     4.039523
# 6       AGE    -0.010535
# 7       DIS    -1.334986
# 8       RAD     0.318273
# 9       TAX    -0.012643
# 10  PTRATIO    -0.977288
# 11        B     0.012671
# 12    LSTAT    -0.462052

# %% [markdown]
# - 왜 RM과 LSTAT의 가중치가 가장 크지 않을까?
# - 독립변수에 들어가는 수치의 단위가 다름(스케일이 다름)
# - ex. NOX: 일산화 질소 농도 -> 스케일이 매우 작음 -> 기울기를 크게
# - ex. Age의 경우 스케일이 크기 대문에 기울기를 작게

# %%
linear_model.intercept_
# Out:
# 31.73035129649783

# %% [markdown]
# MSE, RMSE 확인

# %%
# 예측값들 저장
pre_train = linear_model.predict(X_train)
pre_test = linear_model.predict(X_test)

# %%
pre_train
# Out:
# array([11.4309, 13.7185, 26.4186, 31.6866, 11.0511, 24.7729, 28.9531,
#        32.2259, 15.6178, 30.3854,  9.9983, 34.6405, 25.6395, 20.2432,
#        15.5414, 13.036 , 30.4522, 13.2658, 24.4609, 20.5425, 13.6812,
#        21.8499, 14.1066, 18.6271, 22.1684, 33.4791, 22.3938, 16.7195,
#        30.8946, 38.6076, 26.5084, 25.969 , 15.1705, 15.8474, 35.9205,
#        22.7883, 33.553 , 25.2657, 20.8824, 17.1336, 23.4906, 19.8579,
#        30.3236, 16.4674, 25.5273, 26.7393, 23.9351, 22.7894, 32.9337,
#        18.773 , 30.8384, 28.7822, 13.3372, 32.7834, 27.6637, 19.5787,
#        35.5025, 14.3487, 24.9673, 28.3706, 22.3478, 18.7344, 20.9501,
#        25.0458, 19.914 , 32.3946, 23.7971, 19.401 ,  7.0189,  5.5508,
#        22.3174, 19.6758, 20.9031, 21.4219, 17.661 , 31.3212, 37.6994,
#        20.0529, 13.2866, 27.283 , 16.4181, 25.059 , 18.5833, 24.1286,
#        14.647 , 20.553 , 13.4972, 22.0413, 27.716 , 22.9651, 17.0856,
#        15.406 , 21.3564, 38.8502, 19.8867, 15.169 , 15.1044, 24.6601,
#        17.738 , 21.3095, 25.4068, 17.1175, 28.3853, 17.4109, 18.3969,
#        22.2964, 31.0265, 25.4307, 28.6175, 25.9638, 32.5937, 24.9424,
#        23.3305, 21.9026, 36.4811, 17.9965, 30.5257, 28.3877, 14.0549,
#        35.2138, 22.1195, 15.3888, 15.2776, 13.3987, 30.316 , 14.0137,
#        17.6407, 29.1991, 31.4627, 28.9849, 20.5173, 11.4126, 27.7718,
#        24.7399, 21.1565, 27.8216, 25.4961, 25.6478, 23.4438, 18.5178,
#        17.1329, 12.6951, 19.7093, 24.9956, 13.5977, 34.1353, 35.6498,
#        18.1454, 10.9992, 33.0868, 25.6959, 20.9415, 25.781 , 24.8914,
#        21.3355, 20.1089, 24.6102, 36.3975, 22.2011, 21.0862, 19.2082,
#        21.5514, 23.0398, 33.2341, 15.5344, 18.3963, 15.827 , 31.4418,
#        43.9545, 22.1408, 24.5693,  8.5807, 32.3928, 19.4806, 18.7583,
#        24.3478, 23.5708,  4.8349, 17.6484, 11.8972, 13.4346, 14.8385,
#        20.6871, 37.3707, 30.9398, 20.52  , 11.0928, 39.757 , 21.7716,
#        15.4586, 19.3913, 18.268 , 33.2617, 31.5976, 22.5081, 17.1934,
#        23.285 , 25.3038, 18.5909, 27.4186, 12.3023, 32.1426, 23.8907,
#        16.7837, 25.9479, 22.3596, 27.8846, 26.1096, 35.5146, 28.0167,
#        19.0814, 16.1575, 19.7625, 28.2489, 25.5499, 28.6246, 31.2078,
#        19.6437, 13.3638, 29.7503, 24.5141, 29.0617, 33.6574,  8.5369,
#        23.7326, 24.077 , 18.0611, 39.8392, 21.4012, 24.8914, 20.9415,
#        25.6022, 32.3621, 18.1567, 25.1782, 34.813 , 37.2968,  6.1883,
#        17.6921, 24.2128, 14.375 , 27.9092, 36.2911, 24.1011, 12.9339,
#        12.4216, 18.3279,  2.8212, 22.6953, 12.0443, 31.0495,  5.7389,
#        12.658 , 22.9864, 23.5378,  9.2068, 17.8728, 38.1152, 25.4314,
#         0.8782, 16.3677, 13.3867, 33.3549, 28.9753, 14.253 , 22.4832,
#        33.0882, 23.3471, 28.8088, 18.9464, 19.1869, 26.3102, 20.7918,
#        17.6815, 30.8009, 28.193 , 27.3309,  9.6419, 20.8773, 21.1364,
#        27.3037,  5.6777, 30.5668, 10.6878, 19.4334, 41.4908, 31.1744,
#        13.    , 19.6328, 35.8084, 18.074 , 16.9487, 13.9603, 29.6931,
#        33.9869,  9.9894, 18.2638, 24.3997, 25.3107, 36.8304, 27.2191,
#        20.9749, 32.9695, 19.3079, 24.2659, 20.8035,  6.5931, 37.3426,
#        25.3571, 25.4678, 20.0545, 10.1409, 20.0988, 20.421 ,  8.2682,
#        21.1356, 28.5824, 18.1739, 18.8949, 20.3563, 24.1494, 15.871 ,
#        21.7552, 22.5402, 16.4418, 11.8149, 17.3925, 30.3466, 42.0383,
#        23.0097, 23.2347, 14.7292, 28.4727,  7.9695, 20.7529, 11.5052,
#        43.1869, 20.2083, 21.7661, 27.9471, 20.7132, 15.2923, 17.8465,
#        33.2113, 36.0023, 12.6848, 24.1346, 11.5842, 20.2638, 19.5044,
#        34.6009, 17.8073, 23.8157, 17.017 ])

# %%
train_mse = mean_squared_error(pre_train, y_train)
test_mse = mean_squared_error(pre_test, y_test)

print('train 데이터의 MSE: ', train_mse ** 0.5)
print('test 데이터의 MSE', test_mse)
# Out:
# train 데이터의 MSE:  4.366731254717563
# test 데이터의 MSE 30.697037704088583

# %% [markdown]
# R2 score 확인

# %% [markdown]
# ![image.png](attachment:e044f3bc-8c8e-4720-a01e-970de43a06bd.png)

# %%
linear_model.score(X_train, y_train)
# Out:
# 0.7611598772034452

# %%
linear_model.score(X_test, y_test)

# R2 score
# 0.7 이상: 좋은 모델
# 0.5 이상: 조정 필요
# Out:
# 0.6771696999851693

# %% [markdown]
# ### 선형회귀 모델 데이터 특성확장
# - 선형회귀 모델은 데이터의 분표가 직선의 형태를 많이 벗어나게 되면 예측 정확도가 낮아짐
# - 선형회귀 모델은 모델 튜닝을 위한 하이퍼파라미터가 존재하지 않음
# - 특성확장을 통해 성능을 높여보자

# %%
# copy: 기존의 데이터는 그대로 두면서, 복사하여 새로운 변수명에 넣어줌
# copy 없이 X_train을 새로운 변수에 담아준다면, 변수의 내용이 바뀔 경우 기존 X_train도 바뀔 수 있음
extended_X_train = X_train.copy()

# %%
extended_X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD  TAX  \
# 445  10.67180   0.0  18.10     0  0.740  6.459  94.8   1.9879   24  666
# 428   7.36711   0.0  18.10     0  0.679  6.193  78.1   1.9356   24  666
# 481   5.70818   0.0  18.10     0  0.532  6.750  74.9   3.3317   24  666
# 55    0.01311  90.0   1.22     0  0.403  7.249  21.9   8.6966    5  226
# 488   0.15086   0.0  27.74     0  0.609  5.454  92.7   1.8209    4  711
# ..        ...   ...    ...   ...    ...    ...   ...      ...  ...  ...
# 486   5.69175   0.0  18.10     0  0.583  6.114  79.8   3.5459   24  666
# 189   0.08370  45.0   3.44     0  0.437  7.185  38.9   4.5667    5  398
# 495   0.17899   0.0   9.69     0  0.585  5.670  28.8   2.7986    6  391
# 206   0.22969   0.0  10.59     0  0.489  6.326  52.5   4.3549    4  277
# 355   0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
#
#      PTRATIO       B  LSTAT
# 445     20.2   43.06  23.98
# 428     20.2   96.73  21.52
# 481     20.2  393.07   7.74
# 55      17.9  395.93   4.81
# 488     20.1  395.09  18.06
# ..       ...     ...    ...
# 486     20.2  392.68  14.98
# 189     15.2  396.90   5.39
# 495     19.2  393.29  17.60
# 206     18.6  394.87  10.97
# 355     22.0  376.04   5.57
#
# [354 rows x 13 columns]

# %%
for col1 in X_train.columns: # 13번 반복
    for col2 in X_train.columns: # 13번 반복
        extended_X_train[col1 + 'x' + col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가

# %%
extended_X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD  TAX  ...  \
# 445  10.67180   0.0  18.10     0  0.740  6.459  94.8   1.9879   24  666  ...
# 428   7.36711   0.0  18.10     0  0.679  6.193  78.1   1.9356   24  666  ...
# 481   5.70818   0.0  18.10     0  0.532  6.750  74.9   3.3317   24  666  ...
# 55    0.01311  90.0   1.22     0  0.403  7.249  21.9   8.6966    5  226  ...
# 488   0.15086   0.0  27.74     0  0.609  5.454  92.7   1.8209    4  711  ...
# ..        ...   ...    ...   ...    ...    ...   ...      ...  ...  ...  ...
# 486   5.69175   0.0  18.10     0  0.583  6.114  79.8   3.5459   24  666  ...
# 189   0.08370  45.0   3.44     0  0.437  7.185  38.9   4.5667    5  398  ...
# 495   0.17899   0.0   9.69     0  0.585  5.670  28.8   2.7986    6  391  ...
# 206   0.22969   0.0  10.59     0  0.489  6.326  52.5   4.3549    4  277  ...
# 355   0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334  ...
#
#      LSTATxCHAS  LSTATxNOX   LSTATxRM  LSTATxAGE  LSTATxDIS  LSTATxRAD  \
# 445         0.0   17.74520  154.88682   2273.304  47.669842     575.52
# 428         0.0   14.61208  133.27336   1680.712  41.654112     516.48
# 481         0.0    4.11768   52.24500    579.726  25.787358     185.76
# 55          0.0    1.93843   34.86769    105.339  41.830646      24.05
# 488         0.0   10.99854   98.49924   1674.162  32.885454      72.24
# ..          ...        ...        ...        ...        ...        ...
# 486         0.0    8.73334   91.58772   1195.404  53.117582     359.52
# 189         0.0    2.35543   38.72715    209.671  24.614513      26.95
# 495         0.0   10.29600   99.79200    506.880  49.255360     105.60
# 206         0.0    5.36433   69.39622    575.925  47.773253      43.88
# 355         0.0    2.30041   33.06352    108.615  58.962349      22.28
#
#      LSTATxTAX  LSTATxPTRATIO    LSTATxB  LSTATxLSTAT
# 445   15970.68        484.396  1032.5788     575.0404
# 428   14332.32        434.704  2081.6296     463.1104
# 481    5154.84        156.348  3042.3618      59.9076
# 55     1087.06         86.099  1904.4233      23.1361
# 488   12840.66        363.006  7135.3254     326.1636
# ..         ...            ...        ...          ...
# 486    9976.68        302.596  5882.3464     224.4004
# 189    2145.22         81.928  2139.2910      29.0521
# 495    6881.60        337.920  6921.9040     309.7600
# 206    3038.69        204.042  4331.7239     120.3409
# 355    1860.38        122.540  2094.5428      31.0249
#
# [354 rows x 182 columns]

# %%
extended_X_test = X_test.copy()

# %%
for col1 in X_test.columns: # 13번 반복
    for col2 in X_test.columns: # 13번 반복
        extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# Out:
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# /var/folders/wp/kc67w1qs78j6fmlzz9psj5cw0000gn/T/ipykernel_24103/1351715877.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1 + 'x' + col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가

# %%
# 특성 확장된 train 데이터로 학습
linear_model2 = LinearRegression()
linear_model2.fit(extended_X_train, y_train)
# Out:
# LinearRegression()

# %%
linear_model2.score(extended_X_train, y_train) # 특성 확장 전: 0.76
# Out:
# 0.9332471683804469

# %%
linear_model2.score(extended_X_test, y_test) # 특성 확장 전: 0.67
# Out:
# 0.8093536758913613

# %% [markdown]
# 라쏘(Lasso) 모델 적용

# %%
from sklearn.linear_model import Lasso

# %%
#alpha 값이 높아지면, 규제가 강해지면서 과대적합은 줄어듬, 오차는 커질 수 있음
lasso_model = Lasso() # 알파의 default값: 1

# %%
lasso_model.fit(extended_X_train, y_train)

ㅋ
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.900e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# Lasso()

# %%
sum(lasso_model.coef_ != 0)
# 182개의 특성 중에 94개의 특성이 남았음
# Out:
# 94

# %%
lasso_model.score(extended_X_train, y_train) # 선형회귀 0.93
# Out:
# 0.8804239058511475

# %%
lasso_model.score(extended_X_test, y_test) # 선형회귀 0.81
# Out:
# 0.8390880939300644

# %% [markdown]
# - train에서 r2는 내려갔지만, test에서는 오름
# - 선형회귀 모델에 비해 과대적합이 줄어든 것을 확인할 수 있음

# %% [markdown]
# ### 릿지(Ridge) 모델 적용

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha = 1)

# %%
ridge_model.fit(extended_X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
ridge_model.score(extended_X_train, y_train) # 라쏘 0.88
# Out:
# 0.9290610763450371

# %%
ridge_model.score(extended_X_test, y_test) # 라쏘 0.84
# Out:
# 0.812583798684529

# %% [markdown]
# - alpha값이 1일 떄, 릿지모델에 비해 라쏘 모델이 과대적합 해소에는 더 적합

# %% [markdown]
# ### 하이퍼파라미터 튜닝
# - alpha 값을 바꿔가면서 RMSE를 확인

# %%
# Lasso 모델
# alpha 값에 따라서 RMSE 계산값을 빈 리스트에 담아주기
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
lasso_train_list = []
lasso_test_list = []

for i in alpha_list:
    # alpha 값을 변경하면서 라쏘 모델 불러오기
    lasso_model = Lasso(alpha=i)
    lasso_model.fit(extended_X_train, y_train)

    # 예측값 구하기
    lasso_train_pre = lasso_model.predict(extended_X_train)

    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    lasso_train_RMSE = mean_squared_error(lasso_train_pre, y_train) ** 0.5

    # 빈 리스트에 RMSE 값 넣기
    lasso_train_list.append(lasso_train_RMSE)

    # test
    lasso_test_pre = lasso_model.predict(extended_X_test)

    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    lasso_test_RMSE = mean_squared_error(lasso_test_pre, y_test) ** 0.5

    # 빈 리스트에 RMSE 값 넣기
    lasso_test_list.append(lasso_test_RMSE)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.251e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.541e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.900e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.190e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.334e+00, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
lasso_train_list
# Out:
# [2.5074101228840595,
#  2.551859417452124,
#  2.809064863310481,
#  3.089761827925798,
#  3.4310530199513884,
#  4.072947845655065]

# %%
lasso_test_list
# Out:
# [4.221458972433158,
#  4.243935779449199,
#  3.8032211559519364,
#  3.9116066752700505,
#  4.232941390735927,
#  5.188098568923208]

# %%
# 한글을 쓰기 위한 rc import
from matplotlib import rc
rc('font', family = 'Pretendard')

# %%
plt.figure(figsize=(10, 5))
plt.plot(lasso_train_list, label='train') # train 그래프
plt.plot(lasso_test_list, label='test') # test 그래프
plt.title('Lasso 모델: alpha - RMSE 그래프') # 그래프 제목
plt.xlabel('alpha 값')
plt.xticks(np.arange(6), alpha_list) # x축의 tick 값(x축값 개수, 실제 들어갈 값)
plt.ylabel('RMSE') # y축 라벨
plt.legend()
plt.grid()
plt.show()

# %%
# Ridge 모델
# alpha 값에 따라서 RMSE 계산값을 빈 리스트에 담아주기
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
ridge_train_list = []
ridge_test_list = []

for i in alpha_list:
    # alpha 값을 변경하면서 라쏘 모델 불러오기
    ridge_model = Ridge(alpha=i)
    ridge_model.fit(extended_X_train, y_train)

    # 예측값 구하기
    ridge_train_pre = ridge_model.predict(extended_X_train)

    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    ridge_train_RMSE = mean_squared_error(ridge_train_pre, y_train) ** 0.5

    # 빈 리스트에 RMSE 값 넣기
    ridge_train_list.append(ridge_train_RMSE)

    # test
    ridge_test_pre = ridge_model.predict(extended_X_test)

    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    ridge_test_RMSE = mean_squared_error(ridge_test_pre, y_test) ** 0.5

    # 빈 리스트에 RMSE 값 넣기
    ridge_test_list.append(ridge_test_RMSE)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.53066e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
plt.figure(figsize=(10, 5))
plt.plot(ridge_train_list, label='train') # train 그래프
plt.plot(ridge_test_list, label='test') # test 그래프
plt.title('Ridge 모델: alpha - RMSE 그래프') # 그래프 제목
plt.xlabel('alpha 값')
plt.xticks(np.arange(6), alpha_list) # x축의 tick 값(x축값 개수, 실제 들어갈 값)
plt.ylabel('RMSE') # y축 라벨
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# - Lasso 모델과 Ridge 모델 모두 alpha 값이 10일 때 가장 과대적합 제어에 유리한 것을 볼 수 있음
# - Lasso 모델은 Ridge 모델에 비해, 과대적합 제어가 더 잘된 것을 확인
# - 과대적합 제어를 위해서는 Lasso 모델을 사용하는 것이 유리
# - 그러나 규제의 정도에 따라 Lasso 모델은 오차값이 급격하게 증가함을 확인
# - 모델의 정확한 예측(r2 score)면에서는 Ridge 모델이 더 유리

# %% [markdown]
# ### 시험 힌트
# - 기본적으로 모두 고르시오 문제(왠만하면 정답 개수는 옆에 적어줄 예정)
# - 지도 학습, 비지도 학습 구분 문제(교란용으로 강화학습 포함)
# - 통계는 추론 후에 검증
# - 일반화의 근거
# - 왜 훈련 데이터와 테스트 데이터를 분리하는가
# - 의사결정 나무가 값을 분리하는데 있어서 값의 크기가 중요할까? 순위만 본다, 값의 크기를 안본다 -> 이상치가 있어도 영향을 덜 받지 않나
# - 교차검증
# - 선형회귀의 특징: 이상치에 민감
# - 각종 규제
# - 정밀도 재현율 -> 실생활에서 정밀도가 중요한 경우는? 재현율이 더 중요한 경우는?
# - 통계학적 데이터 분석: 추론 검증이 있다, 가설 세우기
