# %%
# !pip install cvlib
# Out:
# Requirement already satisfied: cvlib in c:\users\smhrd1\anaconda3\lib\site-packages (0.2.7)
# Requirement already satisfied: numpy in c:\users\smhrd1\anaconda3\lib\site-packages (from cvlib) (1.26.4)
# Requirement already satisfied: progressbar in c:\users\smhrd1\anaconda3\lib\site-packages (from cvlib) (2.5)
# Requirement already satisfied: requests in c:\users\smhrd1\anaconda3\lib\site-packages (from cvlib) (2.32.3)
# Requirement already satisfied: pillow in c:\users\smhrd1\anaconda3\lib\site-packages (from cvlib) (10.4.0)
# Requirement already satisfied: imageio in c:\users\smhrd1\anaconda3\lib\site-packages (from cvlib) (2.33.1)
# Requirement already satisfied: imutils in c:\users\smhrd1\anaconda3\lib\site-packages (from cvlib) (0.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests->cvlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests->cvlib) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests->cvlib) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests->cvlib) (2025.4.26)

# %%
# !pip install tensorflow==2.16.2
# Out:
# Requirement already satisfied: tensorflow==2.16.2 in c:\users\smhrd1\anaconda3\lib\site-packages (2.16.2)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow==2.16.2) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.4.0)
# Requirement already satisfied: packaging in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (1.72.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow==2.16.2) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.44.0)
# Requirement already satisfied: rich in c:\users\smhrd1\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (13.7.1)
# Requirement already satisfied: namex in c:\users\smhrd1\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.1.0)
# Requirement already satisfied: optree in c:\users\smhrd1\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smhrd1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow==2.16.2) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow==2.16.2) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\smhrd1\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\smhrd1\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow==2.16.2) (0.1.0)

# %%
import cvlib as cv # 얼굴 탐지하는 기능
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #### 이미지에서 얼굴 탐지

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# absl-py                           2.3.0
# accelerate                        1.7.0
# aiobotocore                       2.12.3
# aiohappyeyeballs                  2.4.0
# aiohttp                           3.10.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.5.1
# anaconda-navigator                2.6.3
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           6.1.3
# astropy-iers-data                 0.2024.9.2.0.33.23
# asttokens                         2.0.5
# astunparse                        1.6.3
# async-lru                         2.0.4
# atomicwrites                      1.4.0
# attrs                             25.3.0
# Automat                           20.2.0
# automodel                         0.5.9
# autopep8                          2.0.4
# Babel                             2.11.0
# bcrypt                            3.2.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# black                             24.8.0
# bleach                            4.1.0
# blinker                           1.6.2
# bokeh                             3.6.0
# boltons                           23.0.0
# botocore                          1.34.69
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# cachetools                        5.3.3
# certifi                           2025.4.26
# cffi                              1.17.1
# chardet                           4.0.0
# charset-normalizer                3.3.2
# chromedriver-autoinstaller        0.6.4
# click                             8.1.7
# cloudpickle                       3.0.0
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.1
# conda                             24.11.3
# conda-build                       24.9.0
# conda-content-trust               0.2.0
# conda_index                       0.5.0
# conda-libmamba-solver             24.9.0
# conda-pack                        0.7.1
# conda-package-handling            2.3.0
# conda_package_streaming           0.10.0
# conda-repo-cli                    1.0.114
# conda-token                       0.5.0+1.g2209e04
# constantly                        23.10.4
# contourpy                         1.2.0
# cookiecutter                      2.6.0
# cryptography                      43.0.0
# cssselect                         1.2.0
# cvlib                             0.2.7
# cx-Oracle                         8.3.0
# cycler                            0.11.0
# cytoolz                           0.12.2
# dask                              2024.8.2
# dask-expr                         1.1.13
# datashader                        0.16.3
# debugpy                           1.6.7
# decorator                         5.1.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2024.8.2
# distro                            1.9.0
# docstring-to-markdown             0.11
# docutils                          0.18.1
# et-xmlfile                        1.1.0
# executing                         0.8.3
# fastapi                           0.115.12
# fastjsonschema                    2.16.2
# filelock                          3.13.1
# flake8                            7.0.0
# Flask                             3.0.3
# flatbuffers                       25.2.10
# fonttools                         4.51.0
# frozendict                        2.4.2
# frozenlist                        1.4.0
# fsspec                            2024.6.1
# gast                              0.6.0
# gensim                            4.3.3
# gitdb                             4.0.7
# GitPython                         3.1.43
# google-pasta                      0.2.0
# greenlet                          3.0.1
# grpcio                            1.72.1
# h11                               0.14.0
# h5py                              3.11.0
# HeapDict                          1.0.1
# holoviews                         1.19.1
# httpcore                          1.0.2
# httpx                             0.27.0
# huggingface-hub                   0.31.2
# hvplot                            0.11.0
# hyperlink                         21.0.0
# idna                              3.7
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# importlib-metadata                7.0.1
# imutils                           0.5.4
# incremental                       22.10.0
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            2.0.7
# intervaltree                      3.1.0
# ipykernel                         6.28.0
# ipython                           8.27.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.8.1
# isort                             5.13.2
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jedi                              0.19.1
# jellyfish                         1.0.1
# Jinja2                            3.1.4
# jiter                             0.10.0
# jmespath                          1.0.1
# joblib                            1.4.2
# jpype1                            1.5.2
# json5                             0.9.6
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.23.0
# jsonschema-specifications         2023.7.1
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.10.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.14.1
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.2.5
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.27.3
# jupyterlab-widgets                1.0.0
# keras                             3.10.0
# keyring                           24.3.1
# kiwisolver                        1.4.4
# konlpy                            0.6.0
# lazy_loader                       0.4
# lazy-object-proxy                 1.10.0
# lckr_jupyterlab_variableinspector 3.1.0
# libarchive-c                      5.1
# libclang                          18.1.1
# libmambapy                        1.5.8
# linkify-it-py                     2.0.0
# llvmlite                          0.43.0
# lmdb                              1.4.1
# locket                            1.0.0
# lxml                              5.2.1
# lz4                               4.3.2
# Markdown                          3.4.1
# markdown-it-py                    2.2.0
# MarkupSafe                        2.1.3
# matplotlib                        3.9.2
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.1.2
# mistune                           2.0.4
# mkl_fft                           1.3.10
# mkl_random                        1.2.7
# mkl-service                       2.4.0
# ml-dtypes                         0.3.2
# more-itertools                    10.3.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.0.4
# multipledispatch                  0.6.0
# mypy                              1.11.2
# mypy-extensions                   1.0.0
# namex                             0.1.0
# navigator-updater                 0.5.1
# nbclient                          0.8.0
# nbconvert                         7.16.4
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.3
# nltk                              3.9.1
# notebook                          7.2.2
# notebook_shim                     0.2.3
# numba                             0.60.0
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.7.0
# openai                            1.79.0
# opencv-contrib-python             4.11.0.86
# opencv-python                     4.11.0.86
# openpyxl                          3.1.5
# opt_einsum                        3.4.0
# optree                            0.16.0
# outcome                           1.3.0.post0
# overrides                         7.4.0
# packaging                         24.1
# pandas                            2.2.2
# pandocfilters                     1.5.0
# panel                             1.5.2
# param                             2.1.1
# paramiko                          2.8.1
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# pathspec                          0.10.3
# patsy                             0.5.6
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            10.4.0
# pip                               24.2
# pkce                              1.0.3
# pkginfo                           1.10.0
# platformdirs                      3.10.0
# plotly                            5.24.1
# pluggy                            1.0.0
# plumbum                           1.9.0
# ply                               3.11
# progressbar                       2.5
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.43
# Protego                           0.1.16
# protobuf                          4.25.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyarrow                           16.1.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.11.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.3
# pydantic                          2.8.2
# pydantic_core                     2.20.1
# pydeck                            0.8.0
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.4
# pyflakes                          3.2.0
# Pygments                          2.15.1
# PyJWT                             2.8.0
# pylint                            2.16.2
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.1.0
# pyOpenSSL                         24.2.1
# pyparsing                         3.1.2
# PyQt5                             5.15.10
# PyQt5-sip                         12.13.0
# PyQtWebEngine                     5.15.6
# PySocks                           1.7.1
# pytesseract                       0.3.13
# pytest                            7.4.4
# python-dateutil                   2.9.0.post0
# python-dotenv                     0.21.0
# python-json-logger                2.0.7
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.10.0
# python-slugify                    5.0.2
# pytoolconfig                      1.2.6
# pytz                              2024.1
# pyviz_comms                       3.0.2
# PyWavelets                        1.7.0
# pywin32                           305.1
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.10
# PyYAML                            6.0.1
# pyzmq                             25.1.2
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.3.1
# qtconsole                         5.5.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# referencing                       0.30.2
# regex                             2024.9.11
# requests                          2.32.3
# requests-file                     1.5.1
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.7.1
# rope                              1.12.0
# rpds-py                           0.10.6
# rpyc                              6.0.2
# Rtree                             1.0.1
# ruamel.yaml                       0.18.6
# ruamel.yaml.clib                  0.2.8
# ruamel-yaml-conda                 0.17.21
# s3fs                              2024.6.1
# safetensors                       0.5.3
# scikit-image                      0.24.0
# scikit-learn                      1.5.1
# scipy                             1.13.1
# Scrapy                            2.11.1
# seaborn                           0.13.2
# selenium                          4.31.0
# semver                            3.0.2
# Send2Trash                        1.8.2
# sentence-transformers             4.1.0
# service-identity                  18.1.0
# setuptools                        75.1.0
# sip                               6.7.12
# six                               1.16.0
# smart-open                        5.2.1
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            7.3.7
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.10
# spyder                            5.5.1
# spyder-kernels                    2.5.0
# SQLAlchemy                        2.0.34
# stack-data                        0.2.0
# starlette                         0.46.2
# statsmodels                       0.14.2
# streamlit                         1.37.1
# sympy                             1.14.0
# tables                            3.10.1
# tabulate                          0.9.0
# tblib                             1.7.0
# tenacity                          8.2.3
# tensorboard                       2.16.2
# tensorboard-data-server           0.7.2
# tensorflow                        2.16.2
# tensorflow-intel                  2.16.2
# termcolor                         3.1.0
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.2.1
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# tinycss2                          1.2.1
# tldextract                        5.1.2
# tokenizers                        0.21.1
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.11.1
# toolz                             0.12.0
# torch                             2.7.0
# tornado                           6.4.1
# tqdm                              4.66.5
# traitlets                         5.14.3
# transformers                      4.51.3
# trio                              0.29.0
# trio-websocket                    0.12.2
# truststore                        0.8.0
# Twisted                           23.10.0
# twisted-iocpsupport               1.0.2
# typing_extensions                 4.11.0
# tzdata                            2023.3
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# undetected-chromedriver           3.5.5
# unicodedata2                      15.1.0
# Unidecode                         1.3.8
# urllib3                           2.2.3
# uvicorn                           0.34.2
# w3lib                             2.1.2
# watchdog                          4.0.1
# wcwidth                           0.2.5
# webdriver-manager                 4.0.2
# webencodings                      0.5.1
# websocket-client                  1.8.0
# websockets                        15.0.1
# Werkzeug                          3.0.3
# whatthepatch                      1.0.2
# wheel                             0.44.0
# widgetsnbextension                3.6.6
# win-inet-pton                     1.1.0
# wrapt                             1.14.1
# wsproto                           1.2.0
# xarray                            2023.6.0
# xlrd                              2.0.1
# xlwings                           0.32.1
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.11.0
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
img = cv2.imread('./data/cute.png')
faces,conf = cv.detect_face(img)
print(faces) # 얼굴 좌표
print(conf) # 신뢰도

cv2.imshow('cute', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[22, 191, 123, 317], [238, 103, 329, 207], [464, 65, 557, 170]]
# [0.9990305, 0.9981894, 0.97535056]

# %%
# 이미지에 사각형 도형 출력하기
import numpy as np
img_bg = np.zeros((480, 640, 3))
line_color = [0, 255, 0] # 사각형 색깔
line_thick = 4 # 사각형 선 두께

# cv2.rectangle(이미지, 좌상단, 우하단, 색상, 두께)
cv2.rectangle(img_bg,(0,240),(240,480),line_color,line_thick)
cv2.rectangle(img_bg,(360,240),(600,480),line_color,cv2.FILLED)


cv2.imshow('img_bg1',img_bg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 첫번째 사람의 얼굴 좌표
faces[0]
# 첫번째 사람의 좌상단 좌표
# Out:
# [22, 191, 123, 317]

# %%
img = cv2.imread('./data/cute.png')
faces, conf = cv.detect_face(img)
color = [0,255,255]
line_thick = 3

# 여러명의 얼굴에 사각형
for i in range(len(faces)):
    # i 0 1 2 
    # putText(이미지, 텍스트, 위치, 글꼴, 글씨크기, 색깔, 두께)
    cv2.putText(img, f'{conf[i]}',(faces[i][0], faces[i][1]-10),cv2.FONT_HERSHEY_PLAIN,2,color,2)
    cv2.rectangle(img, (faces[i][0], faces[i][1]), (faces[i][2],faces[i][3]),color,line_thick)
cv2.imshow('cute',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
faces
# Out:
# [[22, 191, 123, 317], [238, 103, 329, 207], [464, 65, 557, 170]]

# %%
img = cv2.imread('./data/cute.png')
faces, conf = cv.detect_face(img)
color = [0,255,255]
line_thick = 3

# 여러명의 얼굴에 사각형
'''
for i in range(len(faces)):
    # i 0 1 2 
    # putText(이미지, 텍스트, 위치, 글꼴, 글씨크기, 색깔, 두께)
    cv2.putText(img, f'{conf[i]}',(faces[i][0], faces[i][1]-10),cv2.FONT_HERSHEY_PLAIN,2,color,2)
    cv2.rectangle(img, (faces[i][0], faces[i][1]), (faces[i][2],faces[i][3]),color,line_thick)
'''

# 감지된 얼굴에 사각형 씌워주고, 정확도 출력하는 코드
for (x,y,x2,y2), c in zip(faces, conf): # 3명 => 3번 반복
    cv2.putText(img, f'{c:.2f}', (x,y-10),cv2.FONT_HERSHEY_PLAIN,2,color,2)
    cv2.rectangle(img, (x,y), (x2,y2),color,line_thick)

cv2.imshow('cute',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
(x,y,x2,y2), c =  list(zip(faces,conf))[0]

# %% [markdown]
# - 카메라에서 얼굴 탐지 출력하기

# %%
cap = cv2.VideoCapture(0)
color = [0,255,255]
line_th = 3
cnt = 0

while True:
    try:
        ch,frame = cap.read() # ch: 성공여부, frane : 받아온 이미지(프레임)

        # cv2.flip(대상이미지, 1) : 좌우반전
        flip_frame = cv2.flip(frame,1)
        # 실패할 경우 while문 멈추기
        if not ch: # ch가 False일 경우 실행되는 조건문
            print('동영상 재생 끝 or 읽기 실패')
            break

        # 얼굴 탐지(찾기)
        faces, conf = cv.detect_face(flip_frame)
        # faces 각 얼굴의 좌표
        # conf 각 얼굴의 정확도

        # cv2.putText(이미지, 텍스트, 위치, 글꼴)
        for (x, y, x2, y2), c in zip(faces, conf):
            cv2.putText(flip_frame, f'{c:.2f}',(x,y-10), cv2.FONT_HERSHEY_PLAIN, 2, color, 2)
            cv2.rectangle(flip_frame, (x,y),(x2,y2),color,line_th)
        
        cv2.imshow('video', flip_frame)
        key = cv2.waitKey(33)
        if key == ord('q'):
            print('사용자에 의해 종료되었습니다')
            break
        # 사진 찍기, 프레임 저장하기
        if key == ord('w'):
            cnt += 1
            print(f'./data/face_dt{cnt}.png 사진 저장')
            cv2.imwrite(f'./data/face_dt{cnt}.png',flip_frame,params=[cv2.IMWRITE_PNG_COMPRESSION,0])
            
    except:
        print('카메라 읽기 실패 or 영상 끝')
        cap.release() # 카메라 연결 해제
        cv2.destroyAllWindows()
# try문 안에 있는 while문에서 break로 나갔을 경우
cap.release()
cv2.destroyAllWindows()
# Out:
# ./data/face_dt1.png 사진 저장
# 사용자에 의해 종료되었습니다

# %%
# 얼굴 인식이 안됐을 때, 에러가 발생하는 경우가 존재
# 카메라 읽도록 재실행 연결
# 인식이 안될 경우는 카메라 꺼지도록 설정
# try-except : 예외처리
